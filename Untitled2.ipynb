# %% [markdown]
# <a href="https://colab.research.google.com/github/Navya-28/Advanced-Cricket-Tournament-Simulation-Program/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing required packages
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tabulate import tabulate


class Player:
    def __init__(self, name, bowling, batting, fielding, running, experience):
        """
        Represents a player in a cricket team.
        Initialize a Player object with the provided attributes.

        Args:
            name (str): The name of the player.
            bowling (float): The bowling skill of the player.
            batting (float): The batting skill of the player.
            fielding (float): The fielding skill of the player.
            running (float): The running skill of the player.
            experience (float): The experience level of the player.
        """
        self.name = name
        self.bowling = bowling
        self.batting = batting
        self.fielding = fielding
        self.running = running
        self.experience = experience

class Team:

    def __init__(self, name, players):
        """
        Initialize a Team object with the provided attributes.

        Args:
            name (str): The name of the team.
            players (list): The list of Player objects representing the team's players.
        """
        self.name = name
        self.players = players
        self.captain = None
        self.batting_order = players.copy()
        self.bowlers = []

    def select_captain(self, captain):
        """
        Select the captain for the team.

        Args:
            captain (Player): The Player object representing the captain of the team.
        """
        self.captain = captain

    def sending_next_player(self):
        """
        Send the next player from the batting order.

        Returns:
            Player or None: The next Player object from the batting order, or None if the batting order is empty.
        """
        if len(self.batting_order)>0:
            return self.batting_order.pop(0)
        return None

    def choose_bowler(self):
        """
        Choose a bowler randomly from the team's bowlers.

        Returns:
            Player: The Player object representing the chosen bowler.
        """
        return random.choice(self.bowlers)


class Field:
    def __init__(self, size, fan_ratio, pitch_conditions, home_advantage):
        """
        Initialize a Field object with the provided attributes.

        Args:
            size (str): The size of the field.
            fan_ratio (float): The fan ratio of the field.
            pitch_conditions (float): The pitch conditions of the field.
            home_advantage (float): The home advantage of the field.
        """
        self.size = size
        self.fan_ratio = fan_ratio
        self.pitch_conditions = pitch_conditions
        self.home_advantage = home_advantage


class Umpire:
    def __init__(self, field):
        """
        Initialize an Umpire object with the provided attributes.

        Args:
            field (Field): The Field object representing the field conditions.
        """
        self.field = field
        self.scores = 0
        self.wickets = 0
        self.overs = 1

    def update_score(self, runs):
        """
        Update the score based on the runs scored.

        Args:
            runs (int): The runs scored in the ball.
        """
        self.scores += runs

    def update_wickets(self):
        """
        Update the wickets count.
        """
        self.wickets += 1

    def update_overs(self):
        """
        Update the overs count.
        """
        self.overs += 1

    def predict_outcome(self, batsman, bowler):
        """
        Predict the outcome of a ball based on batsman and bowler stats.

        Args:
            batsman (Player): The Player object representing the batsman.
            bowler (Player): The Player object representing the bowler.

        Returns:
            str: The outcome of the ball (either "OUT" or "NOT OUT").
        """
        batting_prob = batsman.batting * self.field.pitch_conditions * random.random()
        bowling_prob = bowler.bowling * self.field.pitch_conditions * random.random()
        if batting_prob > bowling_prob:
            return "OUT"
        return "NOT OUT"

class Commentator:
    def __init__(self, umpire):
        """
        Initialize a Commentator object with the provided attributes.

        Args:
            umpire (Umpire): The Umpire object providing match information.
        """
        self.umpire = umpire

    def describe_ball(self, batsman, bowler):
        """
        Generate a description of the ball played by the batsman.

        Args:
            batsman (Player): The Player object representing the batsman.
            bowler (Player): The Player object representing the bowler.

        Returns:
            str: The description of the ball played by the batsman.
        """
        outcome = self.umpire.predict_outcome(batsman, bowler)
        print("Outcome: ", outcome)
        if outcome == "OUT":
            # Replace 'your_image_filename.jpg' with the actual filename of the uploaded image
            image_path = 'cricket out.jpg'

            # Read the image
            img = mpimg.imread(image_path)

            # Set the figure size (optional, adjust as needed)
            plt.figure(figsize=(4, 2))

            # Display the image
            plt.imshow(img)
            plt.axis('off')  # Hide the axis
            plt.show()

            description = f"{batsman.name} is OUT!"

        else:
            description = f"{batsman.name} plays the shot."

        return description

    def describe_game(self, captain1, captain2, country1, country2, over):
        """
        Provide a description of the cricket match.

        Args:
            captain1 (str): The name of the captain of the first team.
            captain2 (str): The name of the captain of the second team.
            country1 (str): The name of the first team.
            country2 (str): The name of the second team.
            over (int): The total number of overs in the match.
        """
        print("\n---------WELCOME TO THE CRICKET TOURNAMENT ---------\n")
        print(f"{country1} Vs {country2}")
        print(f"INDIA'S CAPTAIN : {captain1}, PAKISTAN'S CAPTAIN : {captain2}")
        print(f"Over : {over}")
        print("\n---------------------------------------------\n")

    def describe_start(self, team):
        """
        Provide a description of the start of an innings.

        Args:
            team (str): The name of the team currently batting.
        """
        print("\n------------- {} Batting ------------------\n".format(team.name))
        headers = ["Player", "Batting", "Bowling", "Fielding", "Running", "Experience"]
        data = [[player.name, player.batting, player.bowling, player.fielding, player.running, player.experience] for player in team.players]

        print(tabulate(data, headers=headers, tablefmt="fancy_grid",numalign="center", stralign="center", colalign=("center", "center")))
        print("\n")
        print("\n")



    def describe_end(self):
        """
        Provide a description of the end of an innings.
        """
        print(f"\n\nFinal Run: {self.umpire.scores} Wicket: {self.umpire.wickets} Overs: {self.umpire.overs}")
        print("\n---------------------------------------------\n")


    def current_info(self, ball_count):
        """
        Provide the current match information.

        Args:
            ball_count (int): The count of balls played in the current over.
        """
        print(f"Balls: {ball_count} Over: {self.umpire.overs} Run: {self.umpire.scores}  Wicket: {self.umpire.wickets}")

    def describe_final_result(self, name, scores):
        """
        Provide a description of the final result of the match.

        Args:
            name (str): The name of the winning team.
            scores (int): The```
            score achieved by the winning team.
        """
        print("--------------- Winner -----------------------")
        # Replace 'your_image_filename.jpg' with the actual filename of the uploaded image
        image_path = 'winner.jpg'

        # Read the image
        img = mpimg.imread(image_path)

        # Set the figure size (optional, adjust as needed)
        plt.figure(figsize=(4, 2))

        # Display the image
        plt.imshow(img)
        plt.axis('off')  # Hide the axis
        plt.show()

        print(f"TEAM : {name} WON BY SCORE: {scores}")
        print("\n---------------------------------------------\n")

class Match:
    def __init__(self, team1, team2, field, total_overs):
        """
        Represents a cricket match between two teams.

        Args:
            team1 (Team): The Team object representing the first team.
            team2 (Team): The Team object representing the second team.
            field (Field): The Field object representing the field conditions.
            total_overs (int): The total number of overs in the match.
        """
        self.team1 = team1
        self.team2 = team2
        self.field = field
        self.umpire = Umpire(field)
        self.commentator = Commentator(self.umpire)
        self.total_overs = total_overs

    def get_match_highlights(self):
        """
        Get the match highlights including top run-scorer, highest wicket-taker, and key moments of the match.
        """
        team1_score = self.commentator.umpire.scores
        team2_score = self.commentator.umpire.scores

        team1_top_scorer = max(self.team1.players, key=lambda player: player.batting).name
        team2_top_scorer = max(self.team2.players, key=lambda player: player.batting).name

        team1_highest_wicket_taker = max(self.team1.players, key=lambda player: player.bowling).name
        team2_highest_wicket_taker = max(self.team2.players, key=lambda player: player.bowling).name

        match_highlights = {
            f"{self.team1.name} Score": team1_score,
            f"{self.team2.name} Score": team2_score,
            f"{self.team1.name} Top Scorer": team1_top_scorer,
            f"{self.team2.name} Top Scorer": team2_top_scorer,
            f"{self.team1.name} Highest Wicket-taker": team1_highest_wicket_taker,
            f"{self.team2.name} Highest Wicket-taker": team2_highest_wicket_taker,
        }
        return match_highlights



    def start_match(self):
        """
        Starts the cricket match.
        """
        self.team1.select_captain(random.choice(self.team1.players))
        self.team2.select_captain(random.choice(self.team2.players))
        self.team1.batting_order = self.team1.players.copy()
        self.team2.batting_order = self.team2.players.copy()
        self.team1.bowlers = self.team1.players.copy()
        self.team2.bowlers = self.team2.players.copy()

        self.commentator.describe_game(self.team1.captain.name, self.team2.captain.name, self.team1.name, self.team2.name, over=self.total_overs)

        # Team 1 playing
        self.commentator.describe_start(self.team1)
        self.play_innings(self.team1, self.team2)

        self.commentator.describe_end()
        lastScores = self.commentator.umpire.scores


        # Team 2 playing
        self.commentator.umpire.scores = 0
        self.commentator.umpire.wickets = 0
        self.commentator.umpire.overs = 0
        self.commentator.describe_start(self.team2)
        self.play_innings(self.team2, self.team1)
        self.commentator.describe_end()
        newScores = self.commentator.umpire.scores

        # Final outcome
        if lastScores > newScores:
            self.commentator.describe_final_result(team1.name, lastScores)
        else:
            self.commentator.describe_final_result(team2.name, newScores)


        highlights = self.get_match_highlights()
        print("\n------- MATCH HIGHLIGHTS -------\n")
        print(tabulate(highlights.items(), headers=["Event", "Description"], tablefmt="fancy_grid", numalign="center", stralign="center", colalign=("center", "center")))


    def play_innings(self, batting_team, bowling_team):
        """
        Simulates the innings of a team.

        Args:
            batting_team (Team): The Team object representing the batting team.
            bowling_team (Team): The Team object representing the bowling team.
        """
        ball_count = 1
        over = 0
        bowler = bowling_team.choose_bowler()
        batsman = batting_team.sending_next_player()


        while over < self.total_overs:
            print("\n")
            self.commentator.current_info(ball_count)
            ball_description = self.commentator.describe_ball(batsman, bowler)

            print(ball_description)
            if ball_description.endswith("OUT!"):
                batsman = batting_team.sending_next_player()
                if batsman is None:
                    break
                self.umpire.update_wickets()
                print(f"Wickets: {self.umpire.wickets} , Overs: {self.umpire.overs}")
                print(f"New player {batsman.name} is playing...")
            else:
                runs = random.randint(0, 6)
                self.umpire.update_score(runs)


            if ball_count > 5:
                over += 1
                print(f"Over {over} Starting...")
                self.umpire.update_overs()
                bowler = bowling_team.choose_bowler()
                ball_count = 0

            self.commentator.current_info(ball_count)
            ball_count += 1



# Creating fake data
# Adding the players
player1_names = ["Rohit Sharma", "Shikhar Dhawan", "Virat Kohli", "KL Rahul", "Rishabh Pant", "Hardik Pandya", "Ravindra Jadeja", "Bhuvneshwar Kumar", "Jasprit Bumrah", "Mohammed Shami", "Yuzvendra Chahal"]
player1 = [Player(name, round(random.random(),1), round(random.random(),1), round(random.random(),1), round(random.random(),1), round(random.random(),1)) for name in player1_names]

player2_names= ["Babar Azam", "Mohammad Rizwan", "Fakhar Zaman", "Imam-ul-Haq", "Shoaib Malik", "Mohammad Hafeez", "Shadab Khan", "Shaheen Afridi", "Hasan Ali", "Haris Rauf", "Wahab Riaz"]
player2 = [Player(name, round(random.random(),1), round(random.random(),1), round(random.random(),1), round(random.random(),1), round(random.random(),1)) for name in player2_names]

# Adding players to team
team1 = Team("INDIA", player1)
team2 = Team("PAKISTAN", player2)

# showing the field
field = Field("Large", 0.7, 0.8, 0.9)

# starting match simulation
total_overs = 4
match = Match(team1, team2, field, total_overs)
match.start_match()
# Out:
# ---------WELCOME TO T20 CRICKET TOURNAMENT ---------
#
# INDIA Vs PAKISTAN
# INDIA'S CAPTAIN : Mohammed Shami, PAKISTAN'S CAPTAIN : Wahab Riaz
# Over : 4
#
# ---------------------------------------------
#
#
# ------------- INDIA Batting ------------------
#
# ╒═══════════════════╤═══════════╤═══════════╤════════════╤═══════════╤══════════════╕
# │      Player       │  Batting  │  Bowling  │  Fielding  │  Running  │  Experience  │
# ╞═══════════════════╪═══════════╪═══════════╪════════════╪═══════════╪══════════════╡
# │   Rohit Sharma    │    0.6    │    0.7    │    0.3     │    0.8    │     0.3      │
# ├───────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │  Shikhar Dhawan   │    0.2    │    0.7    │     1      │    0.1    │     0.4      │
# ├───────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │    Virat Kohli    │    0.6    │    0.4    │    0.1     │    0.7    │     0.8      │
# ├───────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │     KL Rahul      │     1     │    0.6    │    0.5     │    0.7    │     0.7      │
# ├───────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │   Rishabh Pant    │    0.2    │     0     │    0.8     │    0.5    │     0.2      │
# ├───────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │   Hardik Pandya   │    0.3    │    0.2    │     1      │    0.4    │      0       │
# ├───────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │  Ravindra Jadeja  │    0.6    │    0.6    │    0.3     │    0.1    │     0.2      │
# ├───────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │ Bhuvneshwar Kumar │    0.4    │     0     │     1      │    0.3    │     0.4      │
# ├───────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │  Jasprit Bumrah   │    0.7    │    0.6    │    0.3     │    0.4    │     0.7      │
# ├───────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │  Mohammed Shami   │    0.6    │    0.5    │    0.4     │    0.9    │     0.3      │
# ├───────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │ Yuzvendra Chahal  │    0.6    │    0.1    │    0.7     │    0.9    │     0.9      │
# ╘═══════════════════╧═══════════╧═══════════╧════════════╧═══════════╧══════════════╛
#
#
#
#
#
#
# Balls: 1 Over: 1 Run: 0  Wicket: 0
# Outcome:  NOT OUT
# Rohit Sharma plays the shot.
# Balls: 1 Over: 1 Run: 1  Wicket: 0
#
#
# Balls: 2 Over: 1 Run: 1  Wicket: 0
# Outcome:  NOT OUT
# Rohit Sharma plays the shot.
# Balls: 2 Over: 1 Run: 4  Wicket: 0
#
#
# Balls: 3 Over: 1 Run: 4  Wicket: 0
# Outcome:  NOT OUT
# Rohit Sharma plays the shot.
# Balls: 3 Over: 1 Run: 10  Wicket: 0
#
#
# Balls: 4 Over: 1 Run: 10  Wicket: 0
# Outcome:  OUT
# Rohit Sharma is OUT!
# Wickets: 1 , Overs: 1
# New player Shikhar Dhawan is playing...
# Balls: 4 Over: 1 Run: 10  Wicket: 1
#
#
# Balls: 5 Over: 1 Run: 10  Wicket: 1
# Outcome:  NOT OUT
# Shikhar Dhawan plays the shot.
# Balls: 5 Over: 1 Run: 15  Wicket: 1
#
#
# Balls: 6 Over: 1 Run: 15  Wicket: 1
# Outcome:  OUT
# Shikhar Dhawan is OUT!
# Wickets: 2 , Overs: 1
# New player Virat Kohli is playing...
# Over 1 Starting...
# Balls: 0 Over: 2 Run: 15  Wicket: 2
#
#
# Balls: 1 Over: 2 Run: 15  Wicket: 2
# Outcome:  OUT
# Virat Kohli is OUT!
# Wickets: 3 , Overs: 2
# New player KL Rahul is playing...
# Balls: 1 Over: 2 Run: 15  Wicket: 3
#
#
# Balls: 2 Over: 2 Run: 15  Wicket: 3
# Outcome:  OUT
# KL Rahul is OUT!
# Wickets: 4 , Overs: 2
# New player Rishabh Pant is playing...
# Balls: 2 Over: 2 Run: 15  Wicket: 4
#
#
# Balls: 3 Over: 2 Run: 15  Wicket: 4
# Outcome:  OUT
# Rishabh Pant is OUT!
# Wickets: 5 , Overs: 2
# New player Hardik Pandya is playing...
# Balls: 3 Over: 2 Run: 15  Wicket: 5
#
#
# Balls: 4 Over: 2 Run: 15  Wicket: 5
# Outcome:  NOT OUT
# Hardik Pandya plays the shot.
# Balls: 4 Over: 2 Run: 16  Wicket: 5
#
#
# Balls: 5 Over: 2 Run: 16  Wicket: 5
# Outcome:  OUT
# Hardik Pandya is OUT!
# Wickets: 6 , Overs: 2
# New player Ravindra Jadeja is playing...
# Balls: 5 Over: 2 Run: 16  Wicket: 6
#
#
# Balls: 6 Over: 2 Run: 16  Wicket: 6
# Outcome:  OUT
# Ravindra Jadeja is OUT!
# Wickets: 7 , Overs: 2
# New player Bhuvneshwar Kumar is playing...
# Over 2 Starting...
# Balls: 0 Over: 3 Run: 16  Wicket: 7
#
#
# Balls: 1 Over: 3 Run: 16  Wicket: 7
# Outcome:  OUT
# Bhuvneshwar Kumar is OUT!
# Wickets: 8 , Overs: 3
# New player Jasprit Bumrah is playing...
# Balls: 1 Over: 3 Run: 16  Wicket: 8
#
#
# Balls: 2 Over: 3 Run: 16  Wicket: 8
# Outcome:  OUT
# Jasprit Bumrah is OUT!
# Wickets: 9 , Overs: 3
# New player Mohammed Shami is playing...
# Balls: 2 Over: 3 Run: 16  Wicket: 9
#
#
# Balls: 3 Over: 3 Run: 16  Wicket: 9
# Outcome:  NOT OUT
# Mohammed Shami plays the shot.
# Balls: 3 Over: 3 Run: 20  Wicket: 9
#
#
# Balls: 4 Over: 3 Run: 20  Wicket: 9
# Outcome:  NOT OUT
# Mohammed Shami plays the shot.
# Balls: 4 Over: 3 Run: 20  Wicket: 9
#
#
# Balls: 5 Over: 3 Run: 20  Wicket: 9
# Outcome:  NOT OUT
# Mohammed Shami plays the shot.
# Balls: 5 Over: 3 Run: 23  Wicket: 9
#
#
# Balls: 6 Over: 3 Run: 23  Wicket: 9
# Outcome:  OUT
# Mohammed Shami is OUT!
# Wickets: 10 , Overs: 3
# New player Yuzvendra Chahal is playing...
# Over 3 Starting...
# Balls: 0 Over: 4 Run: 23  Wicket: 10
#
#
# Balls: 1 Over: 4 Run: 23  Wicket: 10
# Outcome:  OUT
# Yuzvendra Chahal is OUT!
#
#
# Final Run: 23 Wicket: 10 Overs: 4
#
# ---------------------------------------------
#
#
# ------------- PAKISTAN Batting ------------------
#
# ╒═════════════════╤═══════════╤═══════════╤════════════╤═══════════╤══════════════╕
# │     Player      │  Batting  │  Bowling  │  Fielding  │  Running  │  Experience  │
# ╞═════════════════╪═══════════╪═══════════╪════════════╪═══════════╪══════════════╡
# │   Babar Azam    │    0.3    │    0.2    │    0.4     │    0.5    │     0.1      │
# ├─────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │ Mohammad Rizwan │     1     │    0.9    │    0.9     │    0.1    │      1       │
# ├─────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │  Fakhar Zaman   │    0.3    │     0     │    0.7     │    0.1    │     0.9      │
# ├─────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │   Imam-ul-Haq   │    0.6    │     0     │    0.4     │    0.7    │     0.8      │
# ├─────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │  Shoaib Malik   │    0.9    │    0.8    │    0.4     │     1     │      1       │
# ├─────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │ Mohammad Hafeez │    0.2    │    0.5    │    0.5     │    0.8    │     0.7      │
# ├─────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │   Shadab Khan   │    0.6    │    0.2    │    0.3     │    0.9    │     0.5      │
# ├─────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │ Shaheen Afridi  │    0.3    │    0.7    │    0.4     │    0.8    │     0.1      │
# ├─────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │    Hasan Ali    │    0.9    │    0.2    │    0.6     │    0.1    │      1       │
# ├─────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │   Haris Rauf    │    0.9    │    0.5    │    0.9     │    0.7    │     0.5      │
# ├─────────────────┼───────────┼───────────┼────────────┼───────────┼──────────────┤
# │   Wahab Riaz    │    0.6    │     1     │    0.8     │    0.3    │      0       │
# ╘═════════════════╧═══════════╧═══════════╧════════════╧═══════════╧══════════════╛
#
#
#
#
#
#
# Balls: 1 Over: 0 Run: 0  Wicket: 0
# Outcome:  OUT
# Babar Azam is OUT!
# Wickets: 1 , Overs: 0
# New player Mohammad Rizwan is playing...
# Balls: 1 Over: 0 Run: 0  Wicket: 1
#
#
# Balls: 2 Over: 0 Run: 0  Wicket: 1
# Outcome:  OUT
# Mohammad Rizwan is OUT!
# Wickets: 2 , Overs: 0
# New player Fakhar Zaman is playing...
# Balls: 2 Over: 0 Run: 0  Wicket: 2
#
#
# Balls: 3 Over: 0 Run: 0  Wicket: 2
# Outcome:  OUT
# Fakhar Zaman is OUT!
# Wickets: 3 , Overs: 0
# New player Imam-ul-Haq is playing...
# Balls: 3 Over: 0 Run: 0  Wicket: 3
#
#
# Balls: 4 Over: 0 Run: 0  Wicket: 3
# Outcome:  OUT
# Imam-ul-Haq is OUT!
# Wickets: 4 , Overs: 0
# New player Shoaib Malik is playing...
# Balls: 4 Over: 0 Run: 0  Wicket: 4
#
#
# Balls: 5 Over: 0 Run: 0  Wicket: 4
# Outcome:  OUT
# Shoaib Malik is OUT!
# Wickets: 5 , Overs: 0
# New player Mohammad Hafeez is playing...
# Balls: 5 Over: 0 Run: 0  Wicket: 5
#
#
# Balls: 6 Over: 0 Run: 0  Wicket: 5
# Outcome:  OUT
# Mohammad Hafeez is OUT!
# Wickets: 6 , Overs: 0
# New player Shadab Khan is playing...
# Over 1 Starting...
# Balls: 0 Over: 1 Run: 0  Wicket: 6
#
#
# Balls: 1 Over: 1 Run: 0  Wicket: 6
# Outcome:  NOT OUT
# Shadab Khan plays the shot.
# Balls: 1 Over: 1 Run: 2  Wicket: 6
#
#
# Balls: 2 Over: 1 Run: 2  Wicket: 6
# Outcome:  OUT
# Shadab Khan is OUT!
# Wickets: 7 , Overs: 1
# New player Shaheen Afridi is playing...
# Balls: 2 Over: 1 Run: 2  Wicket: 7
#
#
# Balls: 3 Over: 1 Run: 2  Wicket: 7
# Outcome:  NOT OUT
# Shaheen Afridi plays the shot.
# Balls: 3 Over: 1 Run: 3  Wicket: 7
#
#
# Balls: 4 Over: 1 Run: 3  Wicket: 7
# Outcome:  NOT OUT
# Shaheen Afridi plays the shot.
# Balls: 4 Over: 1 Run: 5  Wicket: 7
#
#
# Balls: 5 Over: 1 Run: 5  Wicket: 7
# Outcome:  NOT OUT
# Shaheen Afridi plays the shot.
# Balls: 5 Over: 1 Run: 5  Wicket: 7
#
#
# Balls: 6 Over: 1 Run: 5  Wicket: 7
# Outcome:  NOT OUT
# Shaheen Afridi plays the shot.
# Over 2 Starting...
# Balls: 0 Over: 2 Run: 6  Wicket: 7
#
#
# Balls: 1 Over: 2 Run: 6  Wicket: 7
# Outcome:  NOT OUT
# Shaheen Afridi plays the shot.
# Balls: 1 Over: 2 Run: 7  Wicket: 7
#
#
# Balls: 2 Over: 2 Run: 7  Wicket: 7
# Outcome:  OUT
# Shaheen Afridi is OUT!
# Wickets: 8 , Overs: 2
# New player Hasan Ali is playing...
# Balls: 2 Over: 2 Run: 7  Wicket: 8
#
#
# Balls: 3 Over: 2 Run: 7  Wicket: 8
# Outcome:  NOT OUT
# Hasan Ali plays the shot.
# Balls: 3 Over: 2 Run: 10  Wicket: 8
#
#
# Balls: 4 Over: 2 Run: 10  Wicket: 8
# Outcome:  OUT
# Hasan Ali is OUT!
# Wickets: 9 , Overs: 2
# New player Haris Rauf is playing...
# Balls: 4 Over: 2 Run: 10  Wicket: 9
#
#
# Balls: 5 Over: 2 Run: 10  Wicket: 9
# Outcome:  NOT OUT
# Haris Rauf plays the shot.
# Balls: 5 Over: 2 Run: 15  Wicket: 9
#
#
# Balls: 6 Over: 2 Run: 15  Wicket: 9
# Outcome:  OUT
# Haris Rauf is OUT!
# Wickets: 10 , Overs: 2
# New player Wahab Riaz is playing...
# Over 3 Starting...
# Balls: 0 Over: 3 Run: 15  Wicket: 10
#
#
# Balls: 1 Over: 3 Run: 15  Wicket: 10
# Outcome:  OUT
# Wahab Riaz is OUT!
#
#
# Final Run: 15 Wicket: 10 Overs: 3
#
# ---------------------------------------------
#
# --------------- Winner -----------------------
# TEAM : INDIA WON BY SCORE: 23
#
# ---------------------------------------------
#
#
# ------- MATCH HIGHLIGHTS -------
#
# ╒═══════════════════════════════╤═════════════════╕
# │             Event             │   Description   │
# ╞═══════════════════════════════╪═════════════════╡
# │          INDIA Score          │       15        │
# ├───────────────────────────────┼─────────────────┤
# │        PAKISTAN Score         │       15        │
# ├───────────────────────────────┼─────────────────┤
# │       INDIA Top Scorer        │    KL Rahul     │
# ├───────────────────────────────┼─────────────────┤
# │      PAKISTAN Top Scorer      │ Mohammad Rizwan │
# ├───────────────────────────────┼─────────────────┤
# │  INDIA Highest Wicket-taker   │  Rohit Sharma   │
# ├───────────────────────────────┼─────────────────┤
# │ PAKISTAN Highest Wicket-taker │   Wahab Riaz    │
# ╘═══════════════════════════════╧═════════════════╛
